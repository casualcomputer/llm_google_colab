# %% [markdown]
# <a href="https://colab.research.google.com/github/casualcomputer/llm_google_colab/blob/main/failed_experiment_local_rag_on_colab_streamlit_localtunnel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Running local-rag (streamlit app) on google colab:
#
# I tried running local-rag (a streamlit app) on streamlit using localtunnel. I successfully received a public url to the app. However, it took forever to localtunnel to redirect me to the app, resulting in a time-out error.. This experiment didn't work... Any feedback or suggestions are appreciated.
#
# Streamlit app for local RAG: https://github.com/jonfairbanks/local-rag

# %%
# !git clone https://github.com/casualcomputer/local-rag.git
# Out:
# Cloning into 'local-rag'...
# remote: Enumerating objects: 835, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 835 (delta 60), reused 111 (delta 59), pack-reused 707
# Receiving objects: 100% (835/835), 55.54 MiB | 22.83 MiB/s, done.
# Resolving deltas: 100% (530/530), done.

# %%
! cd local-rag
! pip install pipenv
! pipenv install #install necessary packages
# Out:
# ...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Installing dependencies from Pipfile.lock (e4eef2)...

# %%
# install ollama and download ollama model

# Install ollama: The Ollama API is now available at 127.0.0.1:11434
! curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Error: could not connect to ollama app, is it running?

# %%
import subprocess
process = subprocess.Popen("ollama serve", shell=True)
# credit: https://stackoverflow.com/questions/78437376/run-ollama-run-llama3-in-colab-raise-err-error-could-not-connect-to-ollama

# %%
# !ollama pull llama3 #download llama3 model
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏ 211 KB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏ 8.8 MB/4.7 GB                  pulling manifest
# ...

# %%
# !pipenv run bash -c "cd local-rag && npm install localtunnel && streamlit run main.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com"
# Out:
# 34.44.94.254
# npm WARN saveError ENOENT: no such file or directory, open '/content/local-rag/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/local-rag/package.json'
# npm WARN local-rag No description
# npm WARN local-rag No repository field.
# npm WARN local-rag No README data
# npm WARN local-rag No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 1.353s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 2 moderate severity vulnerabilities
#   run `npm audit fix` to fix them, or `npm audit` for details
# npx: installed 22 in 3.709s
# your url is: https://fancy-clouds-retire.loca.lt

# %%
## The alternative of pipenv run bash
# !pipenv shell
## Type the following in the shell:
## cd local-rag
## !npm install localtunnel
## streamlit run main.py
## !streamlit run app.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
